# %% [markdown]
# # Task 4 — MLP fundamentals and optimizer comparison
#
# Trains PyTorch MLPs on Dataset A (Adult) with reproducible seeds.

# %%
import os, sys
ROOT = os.path.abspath(os.path.join(os.getcwd(), '..'))
if ROOT not in sys.path:
    sys.path.insert(0, ROOT)
os.chdir(ROOT)
from src.run_task4 import main
main()
