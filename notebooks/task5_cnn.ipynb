# %% [markdown]
# # Task 5 — CIFAR-10 CNN + transfer learning
#
# This run downloads CIFAR-10 on first execution and may take significant time on CPU.

# %%
import os, sys
ROOT = os.path.abspath(os.path.join(os.getcwd(), '..'))
if ROOT not in sys.path:
    sys.path.insert(0, ROOT)
os.chdir(ROOT)
from src.run_task5 import main
main()
# Out:
# /Users/AmirkhanOral/Desktop/ML_DL_Project_Assignment2/.venv/lib/python3.13/site-packages/torchvision/datasets/cifar.py:83: VisibleDeprecationWarning: dtype(): align should be passed as Python or NumPy boolean but got `align=0`. Did you mean to pass a tuple to create a subarray type? (Deprecated NumPy 2.4)
#   entry = pickle.load(f, encoding="latin1")
# /Users/AmirkhanOral/Desktop/ML_DL_Project_Assignment2/.venv/lib/python3.13/site-packages/torch/utils/data/dataloader.py:752: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   super().__init__(loader)
