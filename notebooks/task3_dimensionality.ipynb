# %% [markdown]
# # Task 3 — PCA, t-SNE, UMAP, LDA
#
# Executes `src.run_task3` after switching to the repository root.

# %%
import os, sys
ROOT = os.path.abspath(os.path.join(os.getcwd(), '..'))
if ROOT not in sys.path:
    sys.path.insert(0, ROOT)
os.chdir(ROOT)
from src.run_task3 import main
main()
# Out:
# /Users/AmirkhanOral/Desktop/ML_DL_Project_Assignment2/.venv/lib/python3.13/site-packages/umap/umap_.py:1952: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(
# /Users/AmirkhanOral/Desktop/ML_DL_Project_Assignment2/.venv/lib/python3.13/site-packages/umap/umap_.py:1952: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(
