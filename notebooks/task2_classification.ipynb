# %% [markdown]
# # Task 2 — Classical classification pipelines
#
# Run all cells from the **project root** parent directory (set working directory accordingly), or adjust `sys.path`.
#
# This notebook calls the same entry point as `python -m src.run_task2`.

# %%
import os, sys
ROOT = os.path.abspath(os.path.join(os.getcwd(), '..'))
if ROOT not in sys.path:
    sys.path.insert(0, ROOT)
os.chdir(ROOT)
from src.run_task2 import main
main()
# Out:
# /Users/AmirkhanOral/Desktop/ML_DL_Project_Assignment2/.venv/lib/python3.13/site-packages/sklearn/linear_model/_logistic.py:1135: FutureWarning: 'penalty' was deprecated in version 1.8 and will be removed in 1.10. To avoid this warning, leave 'penalty' set to its default value and use 'l1_ratio' or 'C' instead. Use l1_ratio=0 instead of penalty='l2', l1_ratio=1 instead of penalty='l1', and C=np.inf instead of penalty=None.
#   warnings.warn(
# /Users/AmirkhanOral/Desktop/ML_DL_Project_Assignment2/.venv/lib/python3.13/site-packages/sklearn/linear_model/_logistic.py:1184: FutureWarning: 'n_jobs' has no effect since 1.8 and will be removed in 1.10. You provided 'n_jobs=-1', please leave it unspecified.
#   warnings.warn(msg, category=FutureWarning)
# ...
